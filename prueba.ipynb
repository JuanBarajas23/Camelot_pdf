# %%
import camelot
import matplotlib

# %%
tables = camelot.read_pdf('data/benchmark.pdf', line_scale=40, pages='all',backend="ghostscript")
# Out:
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# c:\Users\juan.barajas\exportapdf\Venv\Lib\site-packages\camelot\parsers\base.py:124: UserWarning: page-5 is image-based, camelot only works on text-based pages.
#   warnings.warn(
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# ...

# %%
tables
# Out:
# <TableList n=10>

# %%
tables[4].df
# Out:
#                          0                                                  1  \
# 0                 Criterio                              Soluciones en la Nube
# 1                 Ejemplos  Adobe Acrobat AI, Microsoft\nCopilot, Google V...
# 2         Facilidad de uso       Muy alta, se consumen vía\nsuscripción o API
# 3   Parsing de\ndocumentos          Integrado en la mayoría\n(Adobe, Copilot)
# 4            Escalabilidad                           Escala masiva en minutos
# 5          Personalización              Limitada (enfocada a casos\nestándar)
# 6  Seguridad y\nprivacidad  Dependencia de la nube →\nriesgo de compliance...
# 7  Infraestructura\nmínima                             Solo acceso a internet
# 8                   Costos                    Pago por suscripción /\nconsumo
# 9        Diferencial clave                              Rapidez y simplicidad
#
#                                                    2  \
# 0
# ...

# %%
camelot.plot(tables[4], kind='grid').show()
# Out:
# C:\Users\juan.barajas\AppData\Local\Temp\ipykernel_4984\1746649403.py:1: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   camelot.plot(tables[4], kind='grid').show()

# %%
tables[0].to_csv('one.csv')
